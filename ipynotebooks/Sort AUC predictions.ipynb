# %% [markdown]
# Going to load up the .csv and sort it so we can see what is supposed to be the best feature!

# %%
cd ..
# Out:
# /media/scott/SPARROWHAWK/neuroglycerin/hail-seizure

# %%
import csv
import numpy as np
import operator

# %%
# csvfnm = 'auc_scores/AUC_scores.csv'
csvfnm = 'auc_scores/batch_k20_AUC_scores.csv'
with open(csvfnm, 'rb') as csvfile:
    cv = csv.reader(csvfile, delimiter='\t')
    sortedlist = sorted(cv, key=operator.itemgetter(8), reverse=True)
    #for row in cv:
    #    print ', '.join(row)

# %%
for row in sortedlist:
    print('{0}\t\t{1}'.format(row[0].ljust(35),row[8]))
# Out:
#                                    		all
# SVC_ica_mvar-ARF                   		0.842726052078
# SVC_ica_mvar-Hphs                  		0.837394192134
# SVC_ica_mvar-DCphs                 		0.837394192134
# SVC_ica_mvar-DTFphs                		0.837394192134
# SVC_csp_mvar-ARF                   		0.835253323975
# SVC_ica_mvar-PDCphs                		0.834443124437
# SVC_ica_mvar-GPDCphs               		0.834443124437
# SVC_ica_mvar-GPDC                  		0.83142702158
# SVC_ica_mvar-PDC                   		0.830573539526
# SVC_ica_mvar-PCOH                  		0.830417986426
# SVC_csp_coher_logf                 		0.830119997868
# SVC_csp_mvar-PCOH                  		0.825075553882
# SVC_ica_phase-high_gamma-sync      		0.824703994889
# SVC_ica_mvar-H                     		0.824522615787
# SVC_csp_mvar-COH                   		0.824124224432
# SVC_ica_mvar-DTF                   		0.823805676096
# SVC_raw_coher_logf                 		0.823717176057
# SVC_ica_mvar-DC                    		0.8234523585
# SVC_csp_phase-high_gamma-sync      		0.823220550047
# SVC_csp_mvar-DTF                   		0.823191579332
# SVC_csp_mvar-H                     		0.823086279439
# SVC_csp_mvar-GPDCphs               		0.821986284688
# SVC_csp_mvar-PDCphs                		0.821986284688
# SVC_ica_coher_logf                 		0.821546446095
# SVC_csp_mvar-DC                    		0.81917103405
# SVC_csp_mvar-Hphs                  		0.818556888069
# SVC_csp_mvar-DTFphs                		0.818556888069
# SVC_csp_mvar-DCphs                 		0.818556888069
# SVC_csp_psd_logf                   		0.818266139599
# SVC_csp_mvar-Sphs                  		0.818111103279
# SVC_csp_mvar-COHphs                		0.818111103279
# SVC_csp_mvar-S                     		0.816873773511
# SVC_raw_mvar-COH                   		0.816693606702
# SVC_ica_mvar-PCOHphs               		0.816497792755
# SVC_csp_mvar-GPDC                  		0.815647231345
# SVC_ica_mvar-Sphs                  		0.815549361931
# SVC_ica_mvar-COHphs                		0.815549361931
# SVC_csp_mvar-PDC                   		0.815511594316
# SVC_raw_spearman                   		0.814638475951
# SVC_raw_corrcoef                   		0.81448357174
# SVC_ica_mvar-COH                   		0.813714557813
# SVC_ica_mvar-S                     		0.81201268767
# SVC_raw_pib_ratioBB                		0.810316741707
# SVC_raw_mvar-DC                    		0.810210454882
# SVC_ica_psd_logf                   		0.809165131215
# SVC_csp_mvar-Pphs                  		0.808484755913
# SVC_raw_mvar-S                     		0.807706613517
# SVC_raw_mvar-DTF                   		0.807163881485
# SVC_ica_corrcoef                   		0.807086856791
# SVC_raw_psd_logf                   		0.806124520854
# SVC_raw_mvar-PCOH                  		0.805777778915
# SVC_csp_mvar-PCOHphs               		0.805319802542
# SVC_raw_xcorr-ypeak                		0.804223250395
# SVC_raw_mvar-H                     		0.803835399262
# SVC_csp_phase-low_gamma-sync       		0.803390079443
# SVC_ica_spearman                   		0.80236699023
# SVC_csp_pib                        		0.801818361218
# SVC_ica_cov                        		0.801632394568
# SVC_ica_pib_ratioBB                		0.801229685064
# SVC_csp_pib_ratioBB                		0.797053840539
# SVC_ica_phase-low_gamma-sync       		0.796814865822
# SVC_csp_phase-delta-sync           		0.796527633782
# SVC_ica_mvar-Pphs                  		0.796040465218
# SVC_ica_xcorr-ypeak                		0.796020625563
# SVC_ica_pib_ratio                  		0.794029316384
# SVC_ica_pib                        		0.793788278437
# SVC_raw_mvar-ARF                   		0.792352528808
# SVC_ica_phase-high_gamma-dif       		0.791145217559
# SVC_csp_pib_ratio                  		0.789202461006
# SVC_ica_mvar-P                     		0.787597383978
# SVC_csp_mvar-P                     		0.78749596187
# SVC_raw_pib_ratio                  		0.787339360965
# SVC_csp_phase-theta-sync           		0.786769980488
# SVC_csp_phase-high_gamma-dif       		0.786644904404
# SVC_raw_pib                        		0.786473614798
# SVC_raw_mvar-PDCphs                		0.785666075572
# SVC_raw_mvar-GPDCphs               		0.785666075572
# SVC_raw_mvar-GPDC                  		0.785275222198
# SVC_ica_phase-delta-sync           		0.78366223288
# SVC_ica_phase-theta-sync           		0.78318485592
# SVC_raw_mvar-Hphs                  		0.781076502103
# SVC_raw_mvar-DTFphs                		0.781076502103
# SVC_raw_mvar-DCphs                 		0.781076502103
# SVC_ica_phase-beta-sync            		0.779635749171
# SVC_raw_ampcorrcoef-delta          		0.779548846095
# SVC_ica_phase-alpha-sync           		0.777038071601
# SVC_csp_phase-alpha-sync           		0.776972068937
# SVC_csp_spearman                   		0.772143847138
# SVC_ica_ampcorrcoef-high_gamma     		0.771404074619
# SVC_csp_ampcorrcoef-high_gamma     		0.76988432313
# SVC_ica_phase-low_gamma-dif        		0.769670135678
# SVC_csp_phase-beta-sync            		0.768708298387
# SVC_raw_cov                        		0.767769207148
# SVC_raw_mvar-Sphs                  		0.765877939408
# SVC_raw_mvar-COHphs                		0.765877939408
# SVC_raw_PSDlogfcorrcoef            		0.765015988135
# SVC_raw_mvar-PDC                   		0.764909589924
# SVC_csp_corrcoef                   		0.763707379116
# SVC_ica_ampcorrcoef-delta          		0.762678799611
# SVC_csp_xcorr-ypeak                		0.762305821095
# SVC_csp_phase-low_gamma-dif        		0.762145091138
# SVC_csp_lmom-2                     		0.762017488147
# SVC_csp_ampcorrcoef-delta          		0.761180658295
# SVC_ica_phase-delta-dif            		0.759480680419
# SVC_ica_pwling2                    		0.757960702273
# SVC_csp_phase-beta-dif             		0.754432027079
# SVC_raw_pwling2                    		0.752945291169
# SVC_ica_PSDlogfcorrcoef            		0.752116762163
# SVC_ica_xcorr-twidth               		0.751478841753
# SVC_csp_phase-delta-dif            		0.750793095315
# SVC_raw_ampcorrcoef-beta           		0.75063987614
# SVC_raw_FFTcorrcoef                		0.750638281767
# SVC_raw_mvar-P                     		0.749279301681
# SVC_csp_PSDlogfcorrcoef            		0.745386899482
# SVC_ica_ampcorrcoef-delta-eig      		0.744917592825
# SVC_raw_lmom-4                     		0.744895108401
# SVC_ica_ampcorrcoef-low_gamma      		0.743886898281
# SVC_ica_act                        		0.742800870812
# SVC_csp_PSDcorrcoef                		0.742083940188
# SVC_ica_ampcorrcoef-beta           		0.741706982862
# SVC_csp_act                        		0.741076565463
# SVC_csp_ampcorrcoef-low_gamma      		0.740360540174
# SVC_csp_var                        		0.740061683841
# SVC_csp_ampcorrcoef-beta           		0.739897684836
# SVC_raw_xcorr-twidth               		0.737765984001
# SVC_ica_ampcorrcoef-alpha          		0.73623527006
# SVC_csp_phase-theta-dif            		0.735243686239
# SVC_ica_PSDcorrcoef                		0.734320720062
# SVC_ica_phase-beta-dif             		0.734303232464
# SVC_ica_ampcorrcoef-beta-eig       		0.73424067888
# SVC_raw_ampcorrcoef-alpha          		0.734224483878
# SVC_raw_act                        		0.733874106353
# SVC_raw_lmom-2                     		0.733833747071
# SVC_raw_mvar-Pphs                  		0.733595495068
# SVC_raw_PSDcorrcoef                		0.733561704968
# SVC_ica_phase-theta-dif            		0.731554089401
# SVC_csp_ampcorrcoef-alpha          		0.730116030456
# SVC_ica_pwling4                    		0.729472409933
# SVC_raw_ampcorrcoef-low_gamma      		0.726932971684
# SVC_raw_lmom-6                     		0.726799311108
# SVC_raw_var                        		0.725647788689
# SVC_raw_ampcorrcoef-theta          		0.725287873417
# SVC_ica_ampcorrcoef-high_gamma-eig 		0.724595885479
# SVC_csp_xcorr-twidth               		0.721965025251
# SVC_ica_ampcorrcoef-theta          		0.720309362154
# SVC_ica_lmom-4                     		0.717721288385
# SVC_csp_ampcorrcoef-theta          		0.715517970256
# SVC_ica_ampcorrcoef-theta-eig      		0.713416526255
# SVC_raw_ampcorrcoef-high_gamma-eig 		0.712604684421
# SVC_ica_phase-alpha-dif            		0.712448890418
# SVC_csp_FFTcorrcoef                		0.712195866822
# SVC_raw_mvar-PCOHphs               		0.711343813358
# SVC_raw_ampcorrcoef-high_gamma     		0.711245660299
# SVC_ica_lmom-6                     		0.705846020696
# SVC_ica_lmom-2                     		0.705652540674
# SVC_csp_ampcorrcoef-high_gamma-eig 		0.7039557904
# SVC_ica_FFTcorrcoef                		0.701493955793
# SVC_csp_pwling2                    		0.698177231265
# SVC_csp_phase-alpha-dif            		0.69810553626
# SVC_raw_ampcorrcoef-low_gamma-eig  		0.697944539495
# SVC_ica_ampcorrcoef-low_gamma-eig  		0.697813623418
# SVC_raw_ampcorrcoef-beta-eig       		0.696267004597
# SVC_ica_ilingam-connweights        		0.695933919096
# SVC_ica_lmom-5                     		0.692474371849
# SVC_csp_lmom-4                     		0.688785590978
# SVC_raw_ampcorrcoef-theta-eig      		0.687374378642
# SVC_raw_pwling1                    		0.68704808121
# SVC_ica_var                        		0.686351282953
# SVC_csp_pwling4                    		0.68544027393
# SVC_raw_lmom-3                     		0.684265980851
# SVC_csp_ampcorrcoef-delta-eig      		0.682428903681
# SVC_raw_ampcorrcoef-delta-eig      		0.682033445923
# SVC_ica_lmom-3                     		0.681622550845
# SVC_raw_ampcorrcoef-alpha-eig      		0.680135329241
# SVC_csp_ampcorrcoef-theta-eig      		0.67997945623
# SVC_ica_pwling1                    		0.679317607264
# SVC_csp_ampcorrcoef-alpha-eig      		0.676403922512
# SVC_raw_pwling4                    		0.675633943672
# SVC_csp_corrcoefeig                		0.675259372078
# SVC_csp_ampcorrcoef-low_gamma-eig  		0.675050950793
# SVC_csp_lmom-3                     		0.673946369789
# SVC_csp_cov                        		0.673806497503
# SVC_raw_lmom-5                     		0.667676400357
# SVC_ica_ampcorrcoef-alpha-eig      		0.666371353099
# SVC_csp_ilingam-connweights        		0.664878511684
# SVC_csp_lmom-6                     		0.664661320696
# SVC_csp_PSDcorrcoefeig             		0.662842111909
# SVC_csp_lmom-5                     		0.654814922572
# SVC_raw_ilingam-connweights        		0.650190252161
# SVC_raw_PSDlogfcorrcoefeig         		0.650188653902
# SVC_ica_corrcoefeig                		0.649374342149
# SVC_raw_PSDcorrcoefeig             		0.646974273654
# SVC_raw_FFTcorrcoefeig             		0.646738925458
# SVC_raw_lmom-1                     		0.646443027329
# SVC_csp_FFTcorrcoefeig             		0.644023389873
# SVC_ica_lmom-1                     		0.643032478253
# SVC_csp_PSDlogfcorrcoefeig         		0.64099793966
# SVC_raw_corrcoefeig                		0.638751863565
# SVC_csp_xcorr-tpeak                		0.638379824059
# SVC_ica_ilingam-causalindex        		0.637721122394
# SVC_ica_PSDlogfcorrcoefeig         		0.636566425475
# SVC_ica_PSDcorrcoefeig             		0.636277215686
# SVC_csp_ilingam-causalindex        		0.635956587281
# SVC_ica_xcorr-tpeak                		0.635521017621
# SVC_ica_FFTcorrcoefeig             		0.635437106424
# SVC_csp_ampcorrcoef-beta-eig       		0.633395146417
# SVC_csp_pwling5                    		0.627766779608
# SVC_csp_lmom-1                     		0.624986706214
# SVC_raw_FFT                        		0.622885108085
# SVC_raw_ilingam-causalindex        		0.61815088439
# SVC_ica_ilingam-causalorder        		0.617185535851
# SVC_csp_pwling1                    		0.615089298496
# SVC_ica_FFT                        		0.614760458614
# SVC_csp_ilingam-causalorder        		0.613570892705
# SVC_ica_pwling5                    		0.610987026995
# SVC_raw_ilingam-causalorder        		0.608432630646
# SVC_raw_pwling5                    		0.606173344952
# SVC_raw_xcorr-tpeak                		0.604138762322
# SVC_csp_FFT                        		0.603685728378

# %% [markdown]
# List the CV scores for a single subject. Specify the subject at the top with nsub, then rerun.

# %%
nsub = 1
with open(csvfnm, 'rb') as csvfile:
    cv = csv.reader(csvfile, delimiter='\t')
    sortedlist = sorted(cv, key=operator.itemgetter(nsub), reverse=True)
for row in sortedlist:
    print('{0}\t\t{1}'.format(row[0].ljust(35),row[nsub]))
# Out:
#                                    		Dog_1
# SVC_ica_PSDlogfcorrcoef            		0.717595557851
# SVC_ica_pib_ratioBB                		0.692861311983
# SVC_raw_PSDlogfcorrcoef            		0.686755681818
# SVC_csp_pib_ratioBB                		0.684772339876
# SVC_raw_pib_ratioBB                		0.673116864669
# SVC_csp_pib                        		0.656056947314
# SVC_ica_phase-low_gamma-sync       		0.648876033058
# SVC_csp_phase-delta-sync           		0.648677944215
# SVC_csp_ampcorrcoef-alpha          		0.644122029959
# SVC_csp_ilingam-causalindex        		0.64255152376
# SVC_csp_PSDcorrcoef                		0.637566244835
# SVC_ica_pib_ratio                  		0.631035253099
# SVC_raw_PSDlogfcorrcoefeig         		0.630544679752
# SVC_ica_pib                        		0.630436596074
# SVC_csp_pib_ratio                  		0.629125129132
# SVC_ica_PSDcorrcoef                		0.628715521694
# SVC_raw_ampcorrcoef-alpha-eig      		0.627829028926
# SVC_csp_ampcorrcoef-theta-eig      		0.623682076446
# SVC_csp_psd_logf                   		0.622622288223
# SVC_ica_phase-high_gamma-sync      		0.621868543388
# SVC_ica_phase-delta-dif            		0.619701833678
# SVC_raw_ampcorrcoef-beta           		0.616467329545
# SVC_raw_mvar-H                     		0.614754907025
# SVC_ica_var                        		0.613235666322
# SVC_ica_psd_logf                   		0.611984891529
# SVC_raw_FFTcorrcoef                		0.611250645661
# SVC_raw_ampcorrcoef-beta-eig       		0.60989759814
# SVC_ica_lmom-2                     		0.609098527893
# SVC_csp_ampcorrcoef-theta          		0.60739294938
# SVC_raw_ampcorrcoef-delta          		0.605789772727
# SVC_csp_phase-high_gamma-sync      		0.60297856405
# SVC_csp_lmom-2                     		0.599060304752
# SVC_raw_psd_logf                   		0.597837422521
# SVC_ica_lmom-6                     		0.596155862603
# SVC_raw_spearman                   		0.594607438017
# SVC_raw_ampcorrcoef-alpha          		0.594505681818
# SVC_ica_cov                        		0.594014721074
# SVC_raw_pib_ratio                  		0.593376936983
# SVC_raw_pib                        		0.586652117769
# SVC_raw_corrcoef                   		0.586062370868
# SVC_csp_ampcorrcoef-alpha-eig      		0.585020661157
# SVC_raw_ampcorrcoef-low_gamma      		0.584408316116
# SVC_ica_PSDlogfcorrcoefeig         		0.58285705062
# SVC_raw_PSDcorrcoef                		0.582522856405
# SVC_ica_ilingam-causalindex        		0.581248966942
# SVC_csp_lmom-5                     		0.581219524793
# SVC_raw_ampcorrcoef-delta-eig      		0.581069214876
# SVC_ica_pwling4                    		0.580149405992
# SVC_raw_lmom-2                     		0.577074896694
# SVC_ica_ilingam-causalorder        		0.576757747934
# SVC_raw_coher_logf                 		0.576203383264
# SVC_csp_var                        		0.575996771694
# SVC_ica_lmom-4                     		0.574867510331
# SVC_raw_ampcorrcoef-high_gamma-eig 		0.574458677686
# SVC_raw_mvar-PCOH                  		0.573552556818
# SVC_csp_phase-alpha-sync           		0.572992639463
# SVC_csp_mvar-S                     		0.57061286157
# SVC_raw_mvar-S                     		0.570099690083
# SVC_ica_phase-delta-sync           		0.568844137397
# SVC_csp_PSDlogfcorrcoef            		0.568060304752
# SVC_ica_phase-beta-sync            		0.56682231405
# SVC_ica_mvar-S                     		0.566787319215
# SVC_csp_pwling5                    		0.565452479339
# SVC_csp_phase-high_gamma-dif       		0.563969137397
# SVC_csp_ilingam-connweights        		0.563586518595
# SVC_csp_lmom-6                     		0.562640883264
# SVC_ica_ampcorrcoef-alpha          		0.562538997934
# SVC_csp_pwling4                    		0.561920325413
# SVC_ica_corrcoef                   		0.561065082645
# SVC_ica_phase-theta-sync           		0.560819602273
# SVC_ica_corrcoefeig                		0.556533316116
# SVC_ica_ampcorrcoef-alpha-eig      		0.556316503099
# SVC_ica_spearman                   		0.554523760331
# SVC_raw_var                        		0.554195893595
# SVC_raw_FFTcorrcoefeig             		0.553463713843
# SVC_raw_ampcorrcoef-theta-eig      		0.553032928719
# SVC_csp_xcorr-twidth               		0.550324767562
# SVC_csp_ampcorrcoef-delta          		0.548619963843
# SVC_csp_ampcorrcoef-delta-eig      		0.547929364669
# SVC_csp_FFTcorrcoef                		0.546828770661
# SVC_csp_coher_logf                 		0.546808367769
# SVC_csp_phase-beta-sync            		0.543825413223
# SVC_raw_lmom-6                     		0.543798166322
# SVC_ica_xcorr-ypeak                		0.54292071281
# SVC_csp_phase-low_gamma-sync       		0.542766141529
# SVC_ica_phase-alpha-sync           		0.539895790289
# SVC_ica_FFTcorrcoef                		0.537923424587
# SVC_raw_ilingam-causalorder        		0.53792303719
# SVC_csp_mvar-PCOH                  		0.53771526343
# SVC_csp_lmom-3                     		0.537427556818
# SVC_csp_xcorr-ypeak                		0.533553073347
# SVC_csp_lmom-4                     		0.53271293905
# SVC_csp_mvar-COH                   		0.532534865702
# SVC_ica_mvar-Hphs                  		0.532412319215
# SVC_ica_mvar-DCphs                 		0.532412319215
# SVC_ica_mvar-DTFphs                		0.532412319215
# SVC_csp_ilingam-causalorder        		0.531980759298
# SVC_raw_mvar-DTF                   		0.531508006198
# SVC_raw_cov                        		0.53121293905
# SVC_ica_ampcorrcoef-theta          		0.530944344008
# SVC_raw_mvar-PDC                   		0.530800748967
# SVC_csp_FFTcorrcoefeig             		0.528012009298
# SVC_csp_ampcorrcoef-high_gamma     		0.527952221074
# SVC_raw_corrcoefeig                		0.52707463843
# SVC_raw_pwling2                    		0.527037448347
# SVC_csp_phase-delta-dif            		0.521678331612
# SVC_ica_phase-alpha-dif            		0.520508522727
# SVC_ica_FFTcorrcoefeig             		0.519465392562
# SVC_raw_pwling1                    		0.51828008781
# SVC_raw_ampcorrcoef-theta          		0.517401859504
# SVC_ica_mvar-PCOH                  		0.517161027893
# SVC_csp_phase-alpha-dif            		0.517076833678
# SVC_ica_mvar-COH                   		0.515581740702
# SVC_ica_mvar-P                     		0.515546745868
# SVC_csp_ampcorrcoef-beta           		0.513175103306
# SVC_raw_lmom-4                     		0.513082257231
# SVC_ica_phase-theta-dif            		0.512350981405
# SVC_ica_lmom-3                     		0.512212293388
# SVC_ica_lmom-5                     		0.51151213843
# SVC_raw_mvar-GPDC                  		0.51047456095
# SVC_raw_xcorr-ypeak                		0.510071410124
# SVC_ica_ampcorrcoef-theta-eig      		0.510016270661
# SVC_ica_coher_logf                 		0.508751291322
# SVC_ica_phase-high_gamma-dif       		0.507878744835
# SVC_csp_ampcorrcoef-high_gamma-eig 		0.507854855372
# SVC_ica_ampcorrcoef-beta           		0.506647339876
# SVC_csp_pwling2                    		0.505599690083
# SVC_raw_FFT                        		0.504769628099
# SVC_ica_mvar-PCOHphs               		0.503120092975
# SVC_raw_mvar-DC                    		0.501326575413
# SVC_ica_PSDcorrcoefeig             		0.501274535124
# SVC_raw_lmom-3                     		0.500881714876
# SVC_ica_pwling5                    		0.499894369835
# SVC_raw_xcorr-twidth               		0.499461389463
# SVC_ica_xcorr-tpeak                		0.499408703512
# SVC_raw_ampcorrcoef-low_gamma-eig  		0.499346203512
# SVC_ica_mvar-H                     		0.497782928719
# SVC_csp_phase-theta-sync           		0.496829545455
# SVC_csp_mvar-P                     		0.496018982438
# SVC_raw_ampcorrcoef-high_gamma     		0.494931172521
# SVC_ica_ampcorrcoef-high_gamma-eig 		0.494557722107
# SVC_ica_mvar-DTF                   		0.49343866219
# SVC_ica_act                        		0.49315392562
# SVC_csp_mvar-ARF                   		0.493145919421
# SVC_ica_ampcorrcoef-low_gamma-eig  		0.492959581612
# SVC_csp_xcorr-tpeak                		0.49179803719
# SVC_ica_phase-beta-dif             		0.490558496901
# SVC_csp_mvar-DTF                   		0.490493543388
# SVC_ica_FFT                        		0.490435950413
# SVC_csp_phase-beta-dif             		0.489739669421
# SVC_csp_mvar-H                     		0.489711002066
# SVC_ica_xcorr-twidth               		0.489457515496
# SVC_raw_mvar-ARF                   		0.486618672521
# SVC_raw_mvar-P                     		0.485526988636
# SVC_raw_ilingam-connweights        		0.48404803719
# SVC_csp_act                        		0.483924328512
# SVC_csp_PSDcorrcoefeig             		0.483358341942
# SVC_csp_mvar-DC                    		0.482997933884
# SVC_ica_phase-low_gamma-dif        		0.482805785124
# SVC_ica_mvar-PDCphs                		0.48226213843
# SVC_ica_mvar-GPDCphs               		0.48226213843
# SVC_ica_mvar-PDC                   		0.480764591942
# SVC_raw_xcorr-tpeak                		0.480141399793
# SVC_ica_mvar-DC                    		0.479139721074
# SVC_raw_mvar-PDCphs                		0.479115444215
# SVC_raw_mvar-GPDCphs               		0.479115444215
# SVC_raw_pwling4                    		0.478784090909
# SVC_csp_cov                        		0.477981792355
# SVC_ica_ilingam-connweights        		0.477765754132
# SVC_csp_spearman                   		0.475301652893
# SVC_ica_pwling2                    		0.475136492769
# SVC_ica_mvar-Pphs                  		0.474790289256
# SVC_raw_mvar-COH                   		0.474367122934
# SVC_raw_PSDcorrcoefeig             		0.47374418905
# SVC_csp_pwling1                    		0.47057928719
# SVC_raw_pwling5                    		0.470537835744
# SVC_csp_mvar-PDC                   		0.470029829545
# SVC_csp_phase-low_gamma-dif        		0.469721203512
# SVC_raw_mvar-Hphs                  		0.465525309917
# SVC_raw_mvar-DTFphs                		0.465525309917
# SVC_raw_mvar-DCphs                 		0.465525309917
# SVC_ica_ampcorrcoef-delta          		0.465418259298
# SVC_ica_mvar-ARF                   		0.465151472107
# SVC_raw_lmom-1                     		0.464453254132
# SVC_csp_phase-theta-dif            		0.464397856405
# SVC_ica_mvar-GPDC                  		0.464239927686
# SVC_csp_mvar-PCOHphs               		0.46396410124
# SVC_csp_mvar-GPDC                  		0.463426652893
# SVC_csp_mvar-Sphs                  		0.461849690083
# SVC_csp_mvar-COHphs                		0.461849690083
# SVC_csp_ampcorrcoef-low_gamma      		0.461779313017
# SVC_ica_mvar-Sphs                  		0.461721978306
# SVC_ica_mvar-COHphs                		0.461721978306
# SVC_raw_lmom-5                     		0.461635330579
# SVC_raw_mvar-Pphs                  		0.46102427686
# SVC_csp_mvar-GPDCphs               		0.460021306818
# SVC_csp_mvar-PDCphs                		0.460021306818
# SVC_ica_ampcorrcoef-high_gamma     		0.458664772727
# SVC_raw_ilingam-causalindex        		0.456352143595
# SVC_csp_ampcorrcoef-beta-eig       		0.454896306818
# SVC_csp_corrcoef                   		0.454351110537
# SVC_csp_PSDlogfcorrcoefeig         		0.453870867769
# SVC_csp_ampcorrcoef-low_gamma-eig  		0.452259555785
# SVC_csp_corrcoefeig                		0.451214359504
# SVC_ica_ampcorrcoef-delta-eig      		0.448398502066
# SVC_csp_FFT                        		0.448077737603
# SVC_csp_mvar-Pphs                  		0.447433367769
# SVC_raw_act                        		0.446746255165
# SVC_ica_ampcorrcoef-low_gamma      		0.444799974174
# SVC_csp_lmom-1                     		0.443824121901
# SVC_ica_pwling1                    		0.442091683884
# SVC_ica_lmom-1                     		0.438183109504
# SVC_raw_mvar-PCOHphs               		0.418517691116
# SVC_csp_mvar-Hphs                  		0.415658961777
# SVC_csp_mvar-DTFphs                		0.415658961777
# SVC_csp_mvar-DCphs                 		0.415658961777
# SVC_raw_mvar-Sphs                  		0.384870996901
# SVC_raw_mvar-COHphs                		0.384870996901
# SVC_ica_ampcorrcoef-beta-eig       		0.337536157025

# %% [markdown]
# Sort by one subject's score and list them all.

# %%
nsub = 8
with open(csvfnm, 'rb') as csvfile:
    cv = csv.reader(csvfile, delimiter='\t')
    sortedlist = sorted(cv, key=operator.itemgetter(nsub), reverse=True)
for row in sortedlist:
    row[0].ljust(35)
    print('{0}\t{1}\t{2}\t{3}\t{4}\t{5}\t{6}\t{7}\t{8}'.format(\
                                                               row[0].ljust(35),\
                                                               row[1][:6],row[2][:6],row[3][:6],row[4][:6],\
                                                               row[5][:6],row[6][:6],row[7][:6],row[8][:6]))
# Out:
#                                    	Dog_1	Dog_2	Dog_3	Dog_4	Dog_5	Patien	Patien	all
# SVC_raw_mvar-GPDCphs               	0.4791	0.8710	0.7498	0.7533	0.8729	0.6373	0.4942	0.7856
# SVC_raw_mvar-GPDC                  	0.5104	0.8475	0.7512	0.7642	0.9078	0.7384	0.3531	0.7852
# SVC_raw_phase-theta-sync           	0.5173	0.8822	0.7915	0.7077	0.9615	0.8167	0.5113	0.7845
# SVC_ica_phase-delta-sync           	0.5688	0.9264	0.7298	0.7299	0.9172	0.8051	0.6149	0.7836
# SVC_ica_phase-theta-sync           	0.5608	0.8075	0.7855	0.7324	0.9202	0.8143	0.5157	0.7831
# SVC_raw_phase-low_gamma-sync       	0.5159	0.9318	0.7036	0.7867	0.8477	0.5064	0.5279	0.7830
# SVC_raw_mvar-Hphs                  	0.4655	0.8223	0.7769	0.7601	0.8500	0.6433	0.5055	0.7810
# SVC_raw_mvar-DTFphs                	0.4655	0.8223	0.7769	0.7601	0.8500	0.6433	0.5055	0.7810
# SVC_raw_mvar-DCphs                 	0.4655	0.8223	0.7769	0.7601	0.8500	0.6433	0.5055	0.7810
# SVC_ica_phase-beta-sync            	0.5668	0.9355	0.7337	0.7270	0.9369	0.8626	0.4919	0.7796
# SVC_raw_ampcorrcoef-delta          	0.6057	0.8598	0.7661	0.7416	0.9121	0.4967	0.5683	0.7795
# SVC_ica_phase-alpha-sync           	0.5398	0.8549	0.7478	0.7299	0.9292	0.8280	0.4578	0.7770
# SVC_csp_phase-alpha-sync           	0.5729	0.8429	0.7782	0.6839	0.9265	0.8333	0.4414	0.7769
# SVC_csp_spearman                   	0.4753	0.9017	0.7325	0.6839	0.8992	0.7590	0.5957	0.7721
# SVC_ica_ampcorrcoef-high_gamma     	0.4586	0.8441	0.7485	0.7703	0.8201	0.6427	0.5595	0.7714
# SVC_csp_ampcorrcoef-high_gamma     	0.5279	0.8243	0.7440	0.7630	0.8033	0.6767	0.5215	0.7698
# SVC_ica_phase-low_gamma-dif        	0.4828	0.8950	0.6715	0.7785	0.8525	0.7329	0.4603	0.7696
# SVC_raw_phase-beta-sync            	0.5175	0.8912	0.7355	0.7437	0.9199	0.8481	0.4647	0.7689
# SVC_raw_phase-alpha-sync           	0.5439	0.8518	0.7599	0.7203	0.9137	0.8451	0.4346	0.7687
# SVC_csp_phase-beta-sync            	0.5438	0.8666	0.7107	0.7536	0.9016	0.8861	0.4726	0.7687
# SVC_raw_cov                        	0.5312	0.9081	0.7763	0.6446	0.9102	0.3083	0.6233	0.7677
# SVC_raw_mvar-Sphs                  	0.3848	0.8947	0.7570	0.7290	0.8075	0.6258	0.4657	0.7658
# SVC_raw_mvar-COHphs                	0.3848	0.8947	0.7570	0.7290	0.8075	0.6258	0.4657	0.7658
# SVC_raw_phase-delta-dif            	0.5503	0.8535	0.7426	0.7344	0.8339	0.5098	0.5601	0.7650
# SVC_raw_PSDlogfcorrcoef            	0.6867	0.7948	0.7323	0.6775	0.9175	0.5503	0.6423	0.7650
# SVC_raw_mvar-PDC                   	0.5308	0.8251	0.7300	0.7156	0.8991	0.7368	0.3507	0.7649
# SVC_csp_corrcoef                   	0.4543	0.9010	0.7308	0.6668	0.8921	0.6420	0.4939	0.7637
# SVC_ica_ampcorrcoef-delta          	0.4654	0.7773	0.7670	0.7393	0.8883	0.8372	0.6017	0.7626
# SVC_csp_xcorr-ypeak                	0.5335	0.8791	0.7505	0.6762	0.8627	0.8196	0.5352	0.7623
# SVC_csp_phase-low_gamma-dif        	0.4697	0.9102	0.6381	0.7835	0.8466	0.7301	0.4239	0.7621
# SVC_csp_lmom-2                     	0.5990	0.8741	0.7278	0.6252	0.9356	0.6355	0.5881	0.7620
# SVC_csp_ampcorrcoef-delta          	0.5486	0.8469	0.7654	0.7294	0.7543	0.8290	0.6092	0.7611
# SVC_ica_phase-delta-dif            	0.6197	0.8855	0.6868	0.7009	0.8262	0.8270	0.5776	0.7594
# SVC_ica_pwling2                    	0.4751	0.8630	0.7195	0.7206	0.8637	0.4648	0.5476	0.7579
# SVC_csp_phase-beta-dif             	0.4897	0.8399	0.6944	0.7476	0.8614	0.8241	0.6026	0.7544
# SVC_raw_pwling2                    	0.5270	0.9081	0.7009	0.7208	0.7955	0.6919	0.7302	0.7529
# SVC_ica_PSDlogfcorrcoef            	0.7175	0.8650	0.6367	0.6858	0.8671	0.8732	0.4949	0.7521
# SVC_ica_xcorr-twidth               	0.4894	0.8573	0.6866	0.7090	0.8570	0.7484	0.6516	0.7514
# SVC_csp_phase-delta-dif            	0.5216	0.8462	0.7109	0.7055	0.8309	0.7477	0.5690	0.7507
# SVC_raw_ampcorrcoef-beta           	0.6164	0.8238	0.7573	0.7289	0.7690	0.6460	0.3305	0.7506
# SVC_raw_FFTcorrcoef                	0.6112	0.8207	0.7067	0.6739	0.8383	0.6546	0.4877	0.7506
# SVC_raw_mvar-P                     	0.4855	0.8284	0.6972	0.7114	0.8722	0.7922	0.4236	0.7492
# SVC_csp_PSDlogfcorrcoef            	0.5680	0.7429	0.6887	0.6839	0.9310	0.8252	0.5767	0.7453
# SVC_ica_ampcorrcoef-delta-eig      	0.4483	0.6681	0.7868	0.6950	0.7552	0.8011	0.4873	0.7449
# SVC_raw_lmom-4                     	0.5130	0.8038	0.7204	0.7308	0.7850	0.6439	0.5942	0.7448
# SVC_ica_ampcorrcoef-low_gamma      	0.4447	0.8357	0.6804	0.7583	0.8127	0.6520	0.6631	0.7438
# SVC_ica_act                        	0.4931	0.8357	0.6863	0.7378	0.7748	0.7166	0.5910	0.7428
# SVC_csp_PSDcorrcoef                	0.6375	0.7824	0.6823	0.7222	0.8477	0.8346	0.4538	0.7420
# SVC_ica_ampcorrcoef-beta           	0.5066	0.7263	0.7534	0.7535	0.8348	0.7810	0.5553	0.7417
# SVC_csp_act                        	0.4839	0.8658	0.6621	0.7229	0.7997	0.6975	0.6187	0.7410
# SVC_csp_ampcorrcoef-low_gamma      	0.4617	0.8110	0.7228	0.7149	0.7980	0.7079	0.5357	0.7403
# SVC_csp_var                        	0.5759	0.8552	0.6813	0.6260	0.9178	0.4390	0.5990	0.7400
# SVC_csp_ampcorrcoef-beta           	0.5131	0.7481	0.7375	0.7411	0.8277	0.8473	0.4687	0.7398
# SVC_raw_phase-high_gamma-dif       	0.5164	0.8825	0.6476	0.7082	0.8732	0.4383	0.6751	0.7386
# SVC_raw_xcorr-twidth               	0.4994	0.8209	0.7038	0.7168	0.8084	0.6227	0.6208	0.7377
# SVC_ica_ampcorrcoef-alpha          	0.5625	0.7542	0.6943	0.7285	0.8724	0.8433	0.4262	0.7362
# SVC_csp_phase-theta-dif            	0.4643	0.8352	0.7174	0.7106	0.7892	0.8313	0.5755	0.7352
# SVC_ica_PSDcorrcoef                	0.6287	0.8278	0.6531	0.7316	0.7672	0.8617	0.5144	0.7343
# SVC_ica_phase-beta-dif             	0.4905	0.7724	0.6782	0.7168	0.9029	0.7110	0.5505	0.7343
# SVC_ica_ampcorrcoef-beta-eig       	0.3375	0.6828	0.7527	0.7618	0.8331	0.7191	0.4173	0.7342
# SVC_raw_ampcorrcoef-alpha          	0.5945	0.8439	0.7120	0.6688	0.7813	0.7500	0.4195	0.7342
# SVC_raw_act                        	0.4467	0.8053	0.6867	0.7077	0.8065	0.8332	0.6201	0.7338
# SVC_raw_lmom-2                     	0.5770	0.8310	0.6827	0.6258	0.9127	0.4451	0.5222	0.7338
# SVC_raw_mvar-Pphs                  	0.4610	0.8683	0.6264	0.7379	0.7826	0.6490	0.5088	0.7335
# SVC_raw_PSDcorrcoef                	0.5825	0.7807	0.7310	0.6945	0.7515	0.6725	0.5828	0.7335
# SVC_ica_phase-theta-dif            	0.5123	0.8156	0.6728	0.7172	0.8011	0.8336	0.6150	0.7315
# SVC_raw_phase-low_gamma-dif        	0.4943	0.9034	0.6442	0.7085	0.8370	0.5022	0.4912	0.7303
# SVC_csp_ampcorrcoef-alpha          	0.6441	0.7857	0.7185	0.7026	0.7143	0.8603	0.4835	0.7301
# SVC_ica_pwling4                    	0.5801	0.8839	0.6822	0.6640	0.7917	0.6504	0.5646	0.7294
# SVC_raw_ampcorrcoef-low_gamma      	0.5844	0.8710	0.6913	0.7305	0.6421	0.5113	0.3844	0.7269
# SVC_raw_lmom-6                     	0.5437	0.7575	0.7414	0.6977	0.7434	0.6462	0.4617	0.7267
# SVC_raw_var                        	0.5541	0.8202	0.6754	0.6137	0.9177	0.3625	0.5944	0.7256
# SVC_raw_ampcorrcoef-theta          	0.5174	0.7910	0.7398	0.6813	0.8258	0.6341	0.5149	0.7252
# SVC_ica_ampcorrcoef-high_gamma-eig 	0.4945	0.6897	0.7707	0.7360	0.6679	0.6736	0.3797	0.7245
# SVC_csp_xcorr-twidth               	0.5503	0.7899	0.6710	0.6944	0.7740	0.7311	0.6596	0.7219
# SVC_ica_ampcorrcoef-theta          	0.5309	0.6672	0.7227	0.7278	0.7561	0.8389	0.6703	0.7203
# SVC_raw_phase-beta-dif             	0.4206	0.8887	0.6920	0.6623	0.7500	0.6328	0.5280	0.7181
# SVC_ica_lmom-4                     	0.5748	0.7613	0.6807	0.6925	0.7569	0.7397	0.6127	0.7177
# SVC_raw_phase-theta-dif            	0.4881	0.8033	0.7272	0.6951	0.6697	0.8322	0.5784	0.7166
# SVC_csp_ampcorrcoef-theta          	0.6073	0.7367	0.7703	0.6830	0.5955	0.8703	0.6875	0.7155
# SVC_ica_ampcorrcoef-theta-eig      	0.5100	0.6412	0.6567	0.7388	0.6870	0.8192	0.7617	0.7134
# SVC_raw_ampcorrcoef-high_gamma-eig 	0.5744	0.7599	0.7058	0.7137	0.5570	0.4076	0.5888	0.7126
# SVC_ica_phase-alpha-dif            	0.5205	0.8127	0.6736	0.6696	0.8277	0.7907	0.5117	0.7124
# SVC_csp_FFTcorrcoef                	0.5468	0.7446	0.6790	0.7053	0.6128	0.4520	0.6911	0.7121
# SVC_raw_mvar-PCOHphs               	0.4185	0.8180	0.6194	0.7103	0.7566	0.8140	0.5017	0.7113
# SVC_raw_ampcorrcoef-high_gamma     	0.4949	0.8297	0.6657	0.7366	0.6245	0.3903	0.3224	0.7112
# SVC_ica_lmom-6                     	0.5961	0.7373	0.6787	0.7126	0.7147	0.6798	0.4527	0.7058
# SVC_ica_lmom-2                     	0.6090	0.8141	0.6608	0.5619	0.8752	0.6884	0.5210	0.7056
# SVC_csp_ampcorrcoef-high_gamma-eig 	0.5078	0.7043	0.7105	0.7196	0.6162	0.6764	0.4210	0.7039
# SVC_ica_FFTcorrcoef                	0.5379	0.7975	0.6301	0.6156	0.7919	0.5223	0.5045	0.7014
# SVC_csp_pwling2                    	0.5055	0.8182	0.6656	0.6425	0.7974	0.3699	0.4617	0.6981
# SVC_csp_phase-alpha-dif            	0.5170	0.7912	0.6575	0.7039	0.7253	0.8302	0.5302	0.6981
# SVC_raw_ampcorrcoef-low_gamma-eig  	0.4993	0.8374	0.6793	0.6818	0.6063	0.5441	0.4717	0.6979
# SVC_ica_ampcorrcoef-low_gamma-eig  	0.4929	0.6754	0.6694	0.7043	0.7554	0.6912	0.4547	0.6978
# SVC_raw_ampcorrcoef-beta-eig       	0.6098	0.7877	0.6597	0.7115	0.5706	0.6417	0.4897	0.6962
# SVC_ica_ilingam-connweights        	0.4777	0.7474	0.6800	0.6635	0.7117	0.5742	0.4040	0.6959
# SVC_ica_lmom-5                     	0.5115	0.8241	0.6140	0.6989	0.6654	0.6320	0.5679	0.6924
# SVC_raw_phase-alpha-dif            	0.4769	0.7834	0.6416	0.6582	0.7554	0.8420	0.5648	0.6891
# SVC_csp_lmom-4                     	0.5327	0.7904	0.6088	0.6823	0.7040	0.5947	0.5215	0.6887
# SVC_raw_ampcorrcoef-theta-eig      	0.5530	0.7730	0.6540	0.6938	0.6706	0.5131	0.6814	0.6873
# SVC_raw_pwling1                    	0.5182	0.8344	0.6697	0.6821	0.7071	0.6491	0.4389	0.6870
# SVC_ica_var                        	0.6132	0.7819	0.6387	0.5673	0.8664	0.5182	0.4765	0.6863
# SVC_csp_pwling4                    	0.5619	0.7871	0.6238	0.6436	0.8155	0.4760	0.4895	0.6854
# SVC_raw_lmom-3                     	0.5008	0.7874	0.6382	0.7006	0.6267	0.7451	0.7052	0.6842
# SVC_csp_ampcorrcoef-delta-eig      	0.5479	0.6193	0.7288	0.6042	0.6778	0.6132	0.4060	0.6824
# SVC_raw_ampcorrcoef-delta-eig      	0.5810	0.6050	0.6907	0.6605	0.7951	0.5191	0.6122	0.6820
# SVC_ica_lmom-3                     	0.5122	0.8141	0.6000	0.6899	0.6477	0.6774	0.6123	0.6816
# SVC_raw_ampcorrcoef-alpha-eig      	0.6278	0.7585	0.6487	0.6566	0.6697	0.5882	0.4890	0.6801
# SVC_csp_ampcorrcoef-theta-eig      	0.6236	0.6404	0.5716	0.7394	0.5759	0.5955	0.6203	0.6799
# SVC_ica_pwling1                    	0.4420	0.8373	0.6886	0.6647	0.7892	0.3246	0.4279	0.6793
# SVC_csp_ampcorrcoef-alpha-eig      	0.5850	0.7287	0.5376	0.7369	0.5631	0.6764	0.3826	0.6764
# SVC_raw_pwling4                    	0.4787	0.7702	0.6441	0.6748	0.7051	0.7326	0.7392	0.6756
# SVC_csp_corrcoefeig                	0.4512	0.7608	0.5163	0.5146	0.8264	0.9538	0.5164	0.6752
# SVC_csp_ampcorrcoef-low_gamma-eig  	0.4522	0.7304	0.7002	0.6530	0.6262	0.7030	0.3368	0.6750
# SVC_csp_lmom-3                     	0.5374	0.7694	0.6010	0.6976	0.6653	0.5975	0.6363	0.6739
# SVC_csp_cov                        	0.4779	0.8158	0.6252	0.6187	0.7274	0.4344	0.4511	0.6738
# SVC_raw_lmom-5                     	0.4616	0.7527	0.6367	0.6566	0.6477	0.4879	0.7063	0.6676
# SVC_ica_ampcorrcoef-alpha-eig      	0.5563	0.6771	0.5342	0.6964	0.7138	0.6440	0.5214	0.6663
# SVC_csp_ilingam-connweights        	0.5635	0.6461	0.5994	0.6719	0.6570	0.5573	0.4798	0.6648
# SVC_csp_lmom-6                     	0.5626	0.7510	0.5829	0.6915	0.6679	0.4589	0.4116	0.6646
# SVC_csp_PSDcorrcoefeig             	0.4833	0.5801	0.6111	0.6813	0.4955	0.7825	0.4240	0.6628
# SVC_csp_lmom-5                     	0.5812	0.7131	0.6412	0.6741	0.6298	0.4947	0.4387	0.6548
# SVC_raw_ilingam-connweights        	0.4840	0.5845	0.6301	0.6563	0.6201	0.4592	0.5616	0.6501
# SVC_raw_PSDlogfcorrcoefeig         	0.6305	0.5761	0.6027	0.6478	0.6960	0.4446	0.6440	0.6501
# SVC_ica_corrcoefeig                	0.5565	0.7333	0.5740	0.5756	0.6439	0.3904	0.4878	0.6493
# SVC_raw_PSDcorrcoefeig             	0.4737	0.5853	0.6189	0.6703	0.4831	0.5776	0.6800	0.6469
# SVC_raw_FFTcorrcoefeig             	0.5534	0.6346	0.6166	0.5388	0.5887	0.5899	0.5269	0.6467
