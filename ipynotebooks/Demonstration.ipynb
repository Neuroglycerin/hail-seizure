# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8, 12
plt.rcParams['axes.grid'] = True

# %%
cd ..
# Out:
# /home/gavin/repositories/hail-seizure

# %%
from python import utils

# %%
with open("probablygood.gavin.json") as f:
    settings = utils.json.load(f)

# %%
# first, need to load metadata
with open("segmentMetadata.json") as f:
    metadata = utils.json.load(f)

# %%
data = utils.get_data(settings)

# %%
features = list(data.keys())
features
# Out:
# ['cln,ica,dwn_feat_pwling1_',
#  'cln,ica,dwn_feat_PSDlogfcorrcoef_',
#  'cln,ica,dwn_feat_xcorr-ypeak_',
#  'cln,csp,dwn_feat_lmom-3_',
#  'cln,csp,dwn_feat_pib_ratioBB_',
#  'cln,ica,dwn_feat_mvar-GPDC_']

# %%
da = utils.DataAssembler(settings,data,metadata)

# %%
X,y = da.build_training(settings['SUBJECTS'][0])

# %%
X
# Out:
# array([[ -4.61903986e-03,   2.98199818e-02,  -4.83764356e-03, ...,
#           2.23365031e-04,  -5.64554574e-05,   2.19557065e-04],
#        [ -8.36969215e-03,   2.07887257e-02,   2.57693529e-03, ...,
#           1.69852142e-05,  -9.84642778e-06,   7.10326917e-05],
#        [ -1.13705135e-02,   5.31479862e-02,  -1.06341009e-04, ...,
#          -1.04715824e-02,  -1.30293835e-03,   2.37567147e-05],
#        ...,
#        [ -9.52378753e-03,  -4.38280848e-03,   7.72467291e-03, ...,
#          -1.03282675e-04,  -5.60951678e-05,  -2.72529299e-04],
#        [ -1.37997414e-02,  -2.14908618e-03,  -9.34220323e-03, ...,
#           4.42561212e-04,   5.18938042e-04,   1.20505867e-04],
#        [ -3.90007260e-02,   7.97198213e-03,  -3.96921678e-03, ...,
#          -9.21221074e-04,   4.66978033e-07,  -4.87561361e-05]])

# %%
X.shape
# Out:
# (924, 3544)

# %%
da.training_segments
# Out:
# array(['Dog_1_interictal_segment_0001.mat',
#        'Dog_1_interictal_segment_0002.mat',
#        'Dog_1_interictal_segment_0003.mat',
#        'Dog_1_interictal_segment_0004.mat',
#        'Dog_1_interictal_segment_0005.mat',
#        'Dog_1_interictal_segment_0006.mat',
#        'Dog_1_interictal_segment_0007.mat',
#        'Dog_1_interictal_segment_0008.mat',
#        'Dog_1_interictal_segment_0009.mat',
#        'Dog_1_interictal_segment_0010.mat',
#        'Dog_1_interictal_segment_0011.mat',
#        'Dog_1_interictal_segment_0012.mat',
#        'Dog_1_interictal_segment_0013.mat',
#        'Dog_1_interictal_segment_0014.mat',
#        'Dog_1_interictal_segment_0015.mat',
#        'Dog_1_interictal_segment_0016.mat',
#        'Dog_1_interictal_segment_0017.mat',
#        'Dog_1_interictal_segment_0018.mat',
#        'Dog_1_interictal_segment_0019.mat',
#        'Dog_1_interictal_segment_0020.mat',
#        'Dog_1_interictal_segment_0021.mat',
# ...

# %%
import sklearn.preprocessing

# %%
import sklearn.svm

# %%
import sklearn.pipeline

# %%
scaler = sklearn.preprocessing.StandardScaler()

# %%
svc = sklearn.svm.SVC(probability=True)

# %%
pipe = sklearn.pipeline.Pipeline([('scl',scaler),('cls',svc)])

# %%
pipe.fit(X,y)
# Out:
# Pipeline(steps=[('scl', StandardScaler(copy=True, with_mean=True, with_std=True)), ('cls', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=True, random_state=None,
#   shrinking=True, tol=0.001, verbose=False))])

# %%
X = da.build_test(settings['SUBJECTS'][0])

# %%
pipe.predict_proba(X)
# Out:
# array([[  9.87433893e-01,   1.25661066e-02],
#        [  9.98279786e-01,   1.72021427e-03],
#        [  9.99850344e-01,   1.49656317e-04],
#        ...,
#        [  5.30980769e-01,   4.69019231e-01],
#        [  9.95017784e-01,   4.98221642e-03],
#        [  9.99948349e-01,   5.16506888e-05]])
